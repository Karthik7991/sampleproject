# %% [markdown]
# <a href="https://colab.research.google.com/github/Karthik7991/sampleproject/blob/master/central_limit_theorem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random 
import matplotlib.pyplot as plt
from statistics import *
from math import *

# %%
s_z = [50,100,150,200,250,300]                             # different sample sizes and 't' is taken as the index number for list s_z
t = 0                                                      

rows, cols = 3, 2                                          # we have arranged the plots in rows and columns
fig, pic = plt.subplots(rows, cols, figsize=(20,15))      
for i in range(0, rows):
  for j in range(0, cols):
                                                                                            
    y = []                                                 # here for all plots we have taken 3000 trails and sample size for each plot varies
    for l in range(0,3000):                                
      x = []
      for n in range(0,s_z[t]):                            # first we generate s_z[t] random numbers and appended them to list 'x' 
        value = random.randint(-20,20)                     # then we find mean of list 'x' and append to list 'y' and through by iteration 
        x.append(value)                                    # we generate 3000 sample means to y 
      k = mean(x)                                          # mu = 0 i.e x =(-20,20)
      s_d = round(stdev(x),2)                              # s_d stands for standard deviation
      s_e = round(s_d/sqrt(s_z[t]),2)                      # s_e stands for standard error
      y.append(k)

    pic[i, j].hist(y, normed = 1)                                                                                                     # ploting histogram diagram
    pic[i, j].set_title(label="sample size:" + str(s_z[t]) +",   standard deviation:" + str(s_d) + ",   standard error:" + str(s_e))    # title to each plot
    t += 1                                                                                                                            # increasing t value by 1 for further plot
    pic[i, j].set_xlabel("mean of samples")                     
    pic[i, j].set_ylabel("distributions")
    pic[i, j].set_xlim(-5,5)
    pic[i, j].set_ylim(0,1)      
plt.show()
plt.savefig('clt.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:20: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
